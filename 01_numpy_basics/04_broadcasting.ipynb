# %% [markdown]
# ### 1. Concept
#
# - Broadcasting allows operations on different shapes

# %% [markdown]
# ### 2. Example

# %%
import numpy as np

a = np.array([[1, 2, 3],
              [4, 5, 6]])

b = np.array([1, 1, 1])

print(a + b)
# Out:
# [[2 3 4]
#  [5 6 7]]

# %% [markdown]
# ### 3. Practice

# %%
# Add 5 to every element
arr = np.array([1, 2, 3])
print(arr + 5)
